# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv("/Users/yannickflores/Perso Project/foreshadownba/foreshadwownba-dvc-data-pipeline/data/processed/nba_games_training_dataset_cleaned_w_features.csv")

# %%
df[df['id']=='2009-11-29_ATL_DET'].head(20)
# Out:
#      id_season                  id  game_nb   game_date extdom   tm  opp  \
# 16        2010  2009-11-29_ATL_DET       17  2009-11-29    dom  ATL  DET
# 590       2010  2009-11-29_ATL_DET       17  2009-11-29    dom  DET  ATL
#
#     results  pts_tm  pts_opp  w_tot  before_average_pts_tm  \
# 16        L      88       94   12.0                  103.3
# 590       W      94       88    6.0                   92.4
#
#      before_average_lastfivegame_pts_tm  before_average_lasttengame_pts_tm  \
# 16                                 94.8                              103.0
# 590                                90.6                               92.8
#
#      diff_all_minus_lastfivegame_pts_tm  diff_all_minus_lasttengame_pts_tm  \
# 16                                  8.5                                0.3
# 590                                 1.8                               -0.4
#
#      before_average_pts_opp  before_average_lastfivegame_pts_opp  \
# ...
