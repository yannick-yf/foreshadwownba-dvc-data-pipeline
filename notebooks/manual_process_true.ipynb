# %%
import pandas as pd
import os

pd.set_option('display.max_columns', None)

# %%
print(os.getcwd())
os.chdir('/Users/yannickflores/Perso Project/foreshadownba/foreshadwownba-dvc-data-pipeline')
os.getcwd()
# Out:
# /Users/yannickflores/Perso Project/foreshadownba/foreshadwownba-dvc-data-pipeline
# '/Users/yannickflores/Perso Project/foreshadownba/foreshadwownba-dvc-data-pipeline'

# %%
nba_games_training_dataset = pd.read_csv('./data/input/nba_games_training_dataset.csv')
nba_games_training_dataset.head()
# Out:
#    id_season  game_nb   game_date extdom   tm  opp results  pts_tm  pts_opp  \
# 0       2015       71  2015-03-25    ext  IND  WAS       W     103      101
# 1       2015       72  2015-03-26    ext  IND  MIL       L     107      111
# 2       2015       73  2015-03-29    dom  IND  DAL       W     104       99
# 3       2015       74  2015-03-31    ext  IND  BRK       L     106      111
# 4       2015       75  2015-04-01    ext  IND  BOS       L      87      100
#
#    fg_tm  fga_tm  fg_prct_tm  3p_tm  3pa_tm  3p_prct_tm  ft_tm  fta_tm  \
# 0     38      85       0.447      9      26       0.346     18      28
# 1     30      71       0.423     14      30       0.467     33      43
# 2     38      76       0.500     10      17       0.588     18      26
# 3     37      82       0.451     12      23       0.522     20      24
# 4     34      81       0.420      6      15       0.400     13      23
#
#    ft_prct_tm  orb_tm  trb_tm  ast_tm  stl_tm  blk_tm  tov_tm  pf_tm  fg_opp  \
# ...
